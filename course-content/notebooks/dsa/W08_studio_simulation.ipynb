# %% [markdown]
# # DSA Week 8 Studio -- SimLab Engine
#
# **Track:** Simulation/Games
# **Product:** SimLab Engine
# **Context:** simulation timestep logs with position, velocity, and score
#
# ---
#
# ## Today's Task
#
# **Full benchmark: baseline vs optimized at 5 input sizes + plots**
#
# **Deliverable:** benchmark_results.json + benchmark_plot.png showing >= 1.5x speedup
#
# ## How Studio Works
#
# 1. **Must-Pass Core** -- Complete this first. Required.
# 2. **Standard Target** -- Expected level for full marks.
# 3. **Stretch Goal** -- For students who finish early.
#
# > Work through each section in order. Ask for help if stuck > 10 minutes.

# %%
# === SETUP (run this first) ===
# If running in Google Colab, uncomment and run the lines below:
# !git clone https://github.com/ArifSolmaz/courseos-curriculum.git
# %cd courseos-curriculum/course-content

import sys, os
# Add src to path so we can import project modules
if os.path.exists('src'):
    sys.path.insert(0, 'src')
elif os.path.exists('../src'):
    sys.path.insert(0, '../src')
elif os.path.exists('../../src'):
    sys.path.insert(0, '../../src')

print("Setup complete! Ready to work.")

# %% [markdown]
# ---
# ## Your Track Data
#
# **SimLab Engine** works with simulation timestep logs with position, velocity, and score.
#
# Here is your sample dataset:

# %%
sample_data = [
    {'step': 0, 'entity': 'player', 'x': 0.0, 'y': 0.0, 'hp': 100},
    {'step': 1, 'entity': 'player', 'x': 1.0, 'y': 0.5, 'hp': 100},
    {'step': 2, 'entity': 'enemy_1', 'x': 2.1, 'y': 1.2, 'hp': 50},
    {'step': 3, 'entity': 'player', 'x': 3.0, 'y': 2.0, 'hp': 95},
    {'step': 4, 'entity': 'enemy_2', 'x': 4.2, 'y': 2.8, 'hp': 75},
    {'step': 5, 'entity': 'player', 'x': 5.0, 'y': 3.5, 'hp': 90},
    {'step': 6, 'entity': 'enemy_1', 'x': 5.9, 'y': 4.1, 'hp': 30},
    {'step': 7, 'entity': 'player', 'x': 6.5, 'y': 4.9, 'hp': 85}
]

print("Loaded " + str(len(sample_data)) + " rows")
print()
for i, row in enumerate(sample_data):
    print("  Row " + str(i) + ": " + str(row))

# %% [markdown]
# ---
# ## Must-Pass Core
#
# You MUST complete this section before moving on.
# This is the minimum required deliverable for today.

# %% [markdown]
# ### Step 1: Implement baseline and optimized versions

# %%
import timeit

# Baseline: check every pair of objects for collision O(n^2)
def baseline_operation(data):
    """Baseline approach for SimLab Engine."""
    # TODO: implement your baseline
    results = []
    for row in data:
        if row["hp"] > 50:
            results.append(row)
    return results

# Optimized: spatial hash grid for O(n) average collision detection
def optimized_operation(data):
    """Optimized approach for SimLab Engine."""
    # TODO: implement your optimized version
    # Use appropriate data structure (set, dict, heap, bisect, etc.)
    results = []
    for row in data:
        if row["hp"] > 50:
            results.append(row)
    return results

# Verify both give same results
r1 = baseline_operation(sample_data)
r2 = optimized_operation(sample_data)
print("Baseline found: " + str(len(r1)) + " results")
print("Optimized found: " + str(len(r2)) + " results")
print("Match: " + str(len(r1) == len(r2)))

# %% [markdown]
# ---
# ## Standard Target
#
# Complete the must-pass core PLUS:

# %%
# Standard target: extend your must-pass work
# - Add error handling for edge cases
# - Include timing measurements
# - Print a clear summary of results

# TODO: Your standard target code here
print("Standard target: extend must-pass with timing + edge cases")

# %% [markdown]
# ---
# ## Stretch Goal
#
# For students who finish early:

# %%
# Stretch: go beyond the standard target
# - Compare multiple approaches
# - Create visualization of results
# - Optimize for a specific edge case

# TODO: Your stretch code here
print("Stretch: additional optimization or visualization")

# %% [markdown]
# ---
# ## Self-Check
#
# Before submitting, verify:

# %%
checklist = [
    "Must-pass core completed",
    "Code runs without errors",
    "Results are printed clearly",
    "Deliverable: benchmark_results.json + benchmark_plot.png showing >= 1.5x speedup",
]

print("=== Studio 8 Self-Check ===")
for item in checklist:
    print("  [ ] " + item)

# %% [markdown]
# ---
# ## Reflection (Required - Complete before submitting)
#
# In the cell below, write 3-5 bullet points:
# 1. **What I learned today:**
# 2. **What was hardest:**
# 3. **What I still don't understand:**
# 4. **What I will review before next week:**
# 5. **If I used AI tools, what for:**

# %%
# YOUR REFLECTION (write as comments or as a multi-line string)
reflection = """
- What I learned:
- What was hardest:
- What I still don't understand:
- What I will review:
- AI tools used (if any):
"""
print(reflection)
