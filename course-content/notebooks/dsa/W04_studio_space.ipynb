# %% [markdown]
# # DSA Week 4 Studio — Lightcurve Explorer
# **Track:** Space/Astro
# **Goal:** Apply DSA optimization to Lightcurve Explorer

# %%
# === SETUP (run this first) ===
# If running in Google Colab, uncomment and run the lines below:
# !git clone https://github.com/YOUR-ORG/YOUR-REPO.git
# %cd YOUR-REPO

import sys, os
# Add src to path so we can import project modules
if os.path.exists('src'):
    sys.path.insert(0, 'src')
elif os.path.exists('../src'):
    sys.path.insert(0, '../src')
elif os.path.exists('../../src'):
    sys.path.insert(0, '../../src')

print("Setup complete! Ready to work.")

# %% [markdown]
# ---
# ## Must-Pass Core

# %%
# Must-pass: benchmark one baseline implementation correctly
# Identify the bottleneck and state the baseline Big-O
print("Working on Lightcurve Explorer DSA optimization...")
print("Must-pass: baseline benchmark + Big-O statement")

# %% [markdown]
# ---
# ## Standard Target

# %%
# Standard: implement optimization and prove improvement
print("Standard: optimized version + timing comparison")

# %% [markdown]
# ---
# ## Stretch

# %%
# Stretch: advanced optimization or additional benchmark
print("Stretch goal")

# %% [markdown]
# ---
# ## Reflection (Required - Complete before submitting)
#
# In the cell below, write 3-5 bullet points:
# 1. **What I learned today:**
# 2. **What was hardest:**
# 3. **What I still don't understand:**
# 4. **What I will review before next week:**
# 5. **If I used AI tools, what for:**

# %%
# YOUR REFLECTION (write as comments or as a multi-line string)
reflection = """
- What I learned:
- What was hardest:
- What I still don't understand:
- What I will review:
- AI tools used (if any):
"""
print(reflection)
