# %% [markdown]
# # DSA Week 10 Studio -- MechaSense Studio
#
# **Track:** Robotics/Mechatronics
# **Product:** MechaSense Studio
# **Context:** sensor readings (temperature, RPM, vibration) from robotic arms
#
# ---
#
# ## Today's Task
#
# **Model a domain problem as a graph and traverse it with BFS/DFS**
#
# **Deliverable:** graph model + traversal producing useful output
#
# ## How Studio Works
#
# 1. **Must-Pass Core** -- Complete this first. Required.
# 2. **Standard Target** -- Expected level for full marks.
# 3. **Stretch Goal** -- For students who finish early.
#
# > Work through each section in order. Ask for help if stuck > 10 minutes.

# %%
# === SETUP (run this first) ===
# If running in Google Colab, uncomment and run the lines below:
# !git clone https://github.com/ArifSolmaz/courseos-curriculum.git
# %cd courseos-curriculum/course-content

import sys, os
# Add src to path so we can import project modules
if os.path.exists('src'):
    sys.path.insert(0, 'src')
elif os.path.exists('../src'):
    sys.path.insert(0, '../src')
elif os.path.exists('../../src'):
    sys.path.insert(0, '../../src')

print("Setup complete! Ready to work.")

# %% [markdown]
# ---
# ## Your Track Data
#
# **MechaSense Studio** works with sensor readings (temperature, RPM, vibration) from robotic arms.
#
# Here is your sample dataset:

# %%
sample_data = [
    {'ts': 0.01, 'sensor': 'motor_A', 'temp': 25.3, 'rpm': 1500},
    {'ts': 0.02, 'sensor': 'motor_A', 'temp': 26.1, 'rpm': 1520},
    {'ts': 0.03, 'sensor': 'motor_B', 'temp': 85.0, 'rpm': 3500},
    {'ts': 0.04, 'sensor': 'motor_A', 'temp': 24.8, 'rpm': 1490},
    {'ts': 0.05, 'sensor': 'motor_B', 'temp': 60.0, 'rpm': 2800},
    {'ts': 0.06, 'sensor': 'motor_A', 'temp': 27.2, 'rpm': 1550},
    {'ts': 0.07, 'sensor': 'gripper', 'temp': 30.0, 'rpm': 0},
    {'ts': 0.08, 'sensor': 'motor_A', 'temp': 23.9, 'rpm': 1480}
]

print("Loaded " + str(len(sample_data)) + " rows")
print()
for i, row in enumerate(sample_data):
    print("  Row " + str(i) + ": " + str(row))

# %% [markdown]
# ---
# ## Must-Pass Core
#
# You MUST complete this section before moving on.
# This is the minimum required deliverable for today.

# %% [markdown]
# ### Step 1: Model your domain as a graph
#
# robot component dependency graph

# %%
# Build a graph for MechaSense Studio
# robot component dependency graph

from collections import deque

graph = {}

def add_edge(g, u, v):
    if u not in g:
        g[u] = []
    g[u].append(v)
    if v not in g:
        g[v] = []
    g[v].append(u)

# TODO: Add edges relevant to your track
# Example:
add_edge(graph, "main_system", "subsystem_A")
add_edge(graph, "main_system", "subsystem_B")
add_edge(graph, "subsystem_A", "component_1")
add_edge(graph, "subsystem_A", "component_2")
add_edge(graph, "subsystem_B", "component_3")

# BFS traversal
def bfs(g, start):
    visited = set()
    queue = deque([start])
    visited.add(start)
    order = []
    while queue:
        node = queue.popleft()
        order.append(node)
        for neighbor in g.get(node, []):
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)
    return order

print("BFS from main_system: " + str(bfs(graph, "main_system")))

# %% [markdown]
# ---
# ## Standard Target
#
# Complete the must-pass core PLUS:

# %%
# Standard target: extend your must-pass work
# - Add error handling for edge cases
# - Include timing measurements
# - Print a clear summary of results

# TODO: Your standard target code here
print("Standard target: extend must-pass with timing + edge cases")

# %% [markdown]
# ---
# ## Stretch Goal
#
# For students who finish early:

# %%
# Stretch: go beyond the standard target
# - Compare multiple approaches
# - Create visualization of results
# - Optimize for a specific edge case

# TODO: Your stretch code here
print("Stretch: additional optimization or visualization")

# %% [markdown]
# ---
# ## Self-Check
#
# Before submitting, verify:

# %%
checklist = [
    "Must-pass core completed",
    "Code runs without errors",
    "Results are printed clearly",
    "Deliverable: graph model + traversal producing useful output",
]

print("=== Studio 10 Self-Check ===")
for item in checklist:
    print("  [ ] " + item)

# %% [markdown]
# ---
# ## Reflection (Required - Complete before submitting)
#
# In the cell below, write 3-5 bullet points:
# 1. **What I learned today:**
# 2. **What was hardest:**
# 3. **What I still don't understand:**
# 4. **What I will review before next week:**
# 5. **If I used AI tools, what for:**

# %%
# YOUR REFLECTION (write as comments or as a multi-line string)
reflection = """
- What I learned:
- What was hardest:
- What I still don't understand:
- What I will review:
- AI tools used (if any):
"""
print(reflection)
