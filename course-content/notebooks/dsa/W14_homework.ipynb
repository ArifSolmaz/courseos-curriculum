# %% [markdown]
# # DSA Week 14 Homework — Final Performance Report
#
# **Due:** Before next week
# **Time:** 2-3 hours

# %% [markdown]
# ---
# ## Review

# %%
# 1. What is the Big-O of this week's main algorithm?
# Answer: 

# 2. When is it better than the naive approach?
# Answer: 

# 3. Write the algorithm from memory (no looking!)

# %% [markdown]
# ---
# ## Practice

# %%
# Practice 1: Implement or apply final performance report
# Include timing measurements

# %%
# Practice 2: Implement or apply final performance report
# Include timing measurements

# %%
# Practice 3: Implement or apply final performance report
# Include timing measurements

# %%
# Practice 4: Implement or apply final performance report
# Include timing measurements

# %%
# Practice 5: Implement or apply final performance report
# Include timing measurements

# %% [markdown]
# ---
# ## Challenge

# %%
# Challenge: Optimize a real-world scenario
# Benchmark your solution at 3 different input sizes
# Plot the results

# %%
# Complexity analysis:
# Baseline: O(?)
# Optimized: O(?)
# Explain WHY the optimized version is faster
