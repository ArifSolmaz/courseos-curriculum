# %% [markdown]
# # OOP Week 12 Homework -- Plugin Exercise
#
# **Due:** Before next week's session
# **Estimated time:** 2-3 hours
# **Grading:** Must-pass (exercises 1-5), Standard (6-8), Stretch (9-12)
#
# ---
#
# ## Instructions
#
# 1. Complete exercises **in order** -- they build on each other
# 2. **Run each cell** and verify it works before moving on
# 3. **Write comments** explaining your thinking
# 4. **Test** your code (at minimum: does it run without errors?)
# 5. Submit this notebook with all cells executed

# %% [markdown]
# ---
# ## Exercise 1 [Must-Pass]: Concept review
#
# In your own words, explain the main concept from this week (plugin exercise). Give a real-world analogy.

# %%
# YOUR ANSWER (as comments or string)

# %% [markdown]
# ---
# ## Exercise 2 [Must-Pass]: Basic implementation
#
# Implement the basic pattern from this week's core notebook with your own example (not copied).

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 3 [Must-Pass]: Second example
#
# Create a different example that uses the same pattern but in a different domain.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 4 [Must-Pass]: Edge cases
#
# Identify 3 edge cases for this week's pattern and write code that handles them.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 5 [Must-Pass]: Tests
#
# Write at least 3 test functions for your implementations.

# %%
# YOUR TESTS HERE
def test_1():
    pass

def test_2():
    pass

def test_3():
    pass

# %% [markdown]
# ---
# ## Exercise 6 [Standard]: Compare approaches
#
# Show 2 different ways to solve the same problem: one using this week's pattern and one without. Compare the trade-offs.

# %%
# Approach 1:

# Approach 2:

# Comparison:

# %% [markdown]
# ---
# ## Exercise 7 [Standard]: Integration
#
# Integrate this week's concept with a component from a previous week.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 8 [Standard]: Error handling
#
# Add proper error handling to your implementation. Use custom exceptions where appropriate.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 9 [Stretch]: Design question
#
# Design (on paper/ASCII first, then code) a system that uses this week's pattern for a domain you are interested in.

# %%
# DESIGN:

# IMPLEMENTATION:

# %% [markdown]
# ---
# ## Exercise 10 [Stretch]: Debugging challenge
#
# The code below has 3 bugs related to this week's topic. Find and fix them.

# %%
# BUGGY CODE (find and fix 3 bugs):
# Bug 1: 
# Bug 2: 
# Bug 3:

# %% [markdown]
# ---
# ## Exercise 11 [Stretch]: Teaching exercise
#
# Write a short tutorial (as comments) explaining this week's concept to someone who has never seen it. Include an example.

# %%
# YOUR TUTORIAL HERE

# %% [markdown]
# ---
# ## Exercise 12 [Stretch]: Reflection
#
# How does this week's concept improve the architecture of your project? Be specific.

# %%
reflection = """
# YOUR REFLECTION HERE
"""
print(reflection)

# %% [markdown]
# ---
# ## Submission Checklist
#
# - [ ] Exercises 1-5 complete and running (Must-Pass)
# - [ ] Exercises 6-8 complete (Standard)
# - [ ] Exercises 9-12 attempted (Stretch)
# - [ ] All cells executed (no errors)
# - [ ] Comments explain your thinking
