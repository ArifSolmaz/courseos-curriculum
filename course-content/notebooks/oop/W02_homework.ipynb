# %% [markdown]
# # OOP Week 2 Homework -- Composition: DataSource & Dataset
#
# **Due:** Before next week's session
# **Estimated time:** 2-3 hours
# **Grading:** Must-pass (exercises 1-5), Standard (6-8), Stretch (9-12)
#
# ---
#
# ## Instructions
#
# 1. Complete exercises **in order** -- they build on each other
# 2. **Run each cell** and verify it works before moving on
# 3. **Write comments** explaining your thinking
# 4. **Test** your code (at minimum: does it run without errors?)
# 5. Submit this notebook with all cells executed

# %% [markdown]
# ---
# ## Exercise 1 [Must-Pass]: Basic composition
#
# Create `Engine` and `Car` classes where Car HAS-A Engine.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 2 [Must-Pass]: Dataset wrapper
#
# Create a `Dataset` class that wraps a list of dicts. Add `get_column()`, `__len__()`, `__str__()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 3 [Must-Pass]: DataSource class
#
# Create a `DataSource` that loads sample data and returns a `Dataset`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 4 [Must-Pass]: Filter method
#
# Add a `filter_rows(column, condition)` method to Dataset that returns a NEW Dataset.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 5 [Must-Pass]: Verify immutability
#
# Prove that filtering does NOT change the original dataset.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 6 [Standard]: Column statistics
#
# Add a `column_stats(name)` method that returns min, max, mean for numeric columns.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 7 [Standard]: Multi-source
#
# Create two DataSources with different data. Load both and compare their Datasets.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 8 [Standard]: Validation
#
# Add column validation to DataSource: raise ValueError if required columns are missing.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 9 [Stretch]: Composition diagram
#
# Draw an ASCII composition diagram showing the has-a relationships in your pipeline.

# %%
# YOUR DIAGRAM HERE

# %% [markdown]
# ---
# ## Exercise 10 [Stretch]: Pipeline class
#
# Create a `MiniPipeline` class that HAS-A DataSource and SimpleCleaner. Add a `run()` method.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 11 [Stretch]: Design question
#
# Why is composition preferred over inheritance in modern Python? Write 3 reasons with examples.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Exercise 12 [Stretch]: Extend Dataset
#
# Add `to_csv_string()` and `from_csv_string(text)` methods to Dataset.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Submission Checklist
#
# - [ ] Exercises 1-5 complete and running (Must-Pass)
# - [ ] Exercises 6-8 complete (Standard)
# - [ ] Exercises 9-12 attempted (Stretch)
# - [ ] All cells executed (no errors)
# - [ ] Comments explain your thinking
