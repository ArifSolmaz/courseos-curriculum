# %% [markdown]
# # OOP Week 9 Studio -- Lightcurve Explorer
#
# **Track:** Space/Astro
# **Topic:** Factory & Registry Pattern
# **Goal:** Apply this week's OOP concepts to Lightcurve Explorer
# **Time:** ~2 hours
#
# ---
#
# ## How This Studio Works
#
# 1. **Read** the core notebook first (if you have not already)
# 2. **Follow** the step-by-step instructions below
# 3. **Complete** the Must-Pass Core first
# 4. **Then** tackle Standard and Stretch goals
# 5. **Test** your code at each step

# %%
# === SETUP (run this first) ===
# If running in Google Colab, uncomment and run the lines below:
# !git clone https://github.com/ArifSolmaz/courseos-curriculum.git
# %cd courseos-curriculum/course-content

import sys, os
# Add src to path so we can import project modules
if os.path.exists('src'):
    sys.path.insert(0, 'src')
elif os.path.exists('../src'):
    sys.path.insert(0, '../src')
elif os.path.exists('../../src'):
    sys.path.insert(0, '../../src')

print("Setup complete! Ready to work.")

# %% [markdown]
# ---
# ## Your Domain: Lightcurve Explorer
#
# Your project works with brightness measurements over time (lightcurves). This week you will apply **factory & registry pattern** to your Lightcurve Explorer codebase.
#
# Think about:
# - What classes does your domain need?
# - What data does each class hold?
# - What operations does each class perform?

# %% [markdown]
# ---
# ## Must-Pass Core
#
# Complete ALL of these before moving on. This is your minimum requirement for the week.
#
# Apply this week's pattern to Lightcurve Explorer.
#
# 1. Create the class described below
# 2. Add at least 2 methods
# 3. Write at least 2 tests

# %% [markdown]
# ### Step 1: Create Your Class

# %%
# Create a class for your domain
# It should apply this week's concept to Lightcurve Explorer

class LightcurveAnalyzer:
    """LightcurveAnalyzer for Lightcurve Explorer."""

    def __init__(self):
        # TODO: add attributes
        pass

    def detect_transit(self):
        # TODO: implement
        pass

    def __str__(self):
        return "LightcurveAnalyzer(...)"


# Test it
obj = LightcurveAnalyzer()
print(obj)

# %% [markdown]
# **Expected:** Your class should create without errors and print a description.

# %% [markdown]
# ### Step 2: Add Domain-Specific Methods

# %%
# Add methods specific to Lightcurve Explorer
# Think: what operations does your domain need?

# YOUR CODE HERE

# %% [markdown]
# **Expected:** Methods should handle normal input and edge cases.

# %% [markdown]
# ### Step 3: Test Your Code

# %%
# Write at least 2 tests
def test_lightcurveanalyzer_creation():
    obj = LightcurveAnalyzer()
    assert obj is not None
    print("[PASS] test_lightcurveanalyzer_creation")

def test_lightcurveanalyzer_method():
    obj = LightcurveAnalyzer()
    # TODO: test detect_transit()
    print("[PASS] test_lightcurveanalyzer_method")

test_lightcurveanalyzer_creation()
test_lightcurveanalyzer_method()

# %% [markdown]
# **All tests should pass before moving on.**

# %% [markdown]
# ---
# ## Standard Target
#
# Extend your Must-Pass work with these additions.
#
# 1. Add at least 2 more methods to your class
# 2. Add error handling (raise exceptions on bad input)
# 3. Write 2 more tests

# %%
# YOUR STANDARD IMPLEMENTATION

# %% [markdown]
# ### Standard Test

# %%
# Write 2 more tests for your standard features

# YOUR TESTS HERE

# %% [markdown]
# ---
# ## Stretch Goal
#
# Go beyond the requirements:
# - Add a visualization method
# - Add a `to_dict()` method for JSON export
# - Compose with another class from a previous week

# %%
# YOUR STRETCH IMPLEMENTATION

# %% [markdown]
# ---
# ## Additional Practice
#
# Complete these exercises to deepen your understanding.

# %% [markdown]
# ### Exercise: Refactoring Check
#
# Review the code you wrote above. Ask yourself:
# 1. Does each class have exactly ONE responsibility?
# 2. Are all attributes initialized in `__init__`?
# 3. Do methods that transform data return NEW objects?
# 4. Are there any 'magic numbers' that should be parameters?

# %%
# Refactoring notes:
# - Things I would change:
# - Why:
# - Improved version (if needed):

# %% [markdown]
# ### Exercise: Edge Case Testing
#
# Write tests for edge cases specific to Lightcurve Explorer.

# %%
# Edge case tests for Lightcurve Explorer

def test_empty_input():
    # What happens with no data?
    # YOUR CODE HERE
    print("[PASS] test_empty_input")

def test_invalid_input():
    # What happens with wrong type/format?
    # YOUR CODE HERE
    print("[PASS] test_invalid_input")

def test_boundary_values():
    # What happens at the limits?
    # YOUR CODE HERE
    print("[PASS] test_boundary_values")

# Run tests
test_empty_input()
test_invalid_input()
test_boundary_values()

# %% [markdown]
# ### Exercise: Write Documentation
#
# Add proper docstrings to all your classes and methods. Include:
# - One-line summary
# - Parameters (with types)
# - Return values
# - Example usage

# %%
# Copy your main class here with FULL docstrings:

# YOUR CODE HERE

# %% [markdown]
# ### Exercise: Design Diagram
#
# Draw an ASCII class diagram showing ALL the classes you created today and their relationships.

# %%
# ASCII Class Diagram for Lightcurve Explorer
# 
# +------------------+     +------------------+
# |   ClassName1     |---->|   ClassName2     |
# +------------------+     +------------------+
# | - attributes     |     | - attributes     |
# +------------------+     +------------------+
# | + methods        |     | + methods        |
# +------------------+     +------------------+
# 
# YOUR DIAGRAM:

# %% [markdown]
# ### Exercise: Integration Plan
#
# How will today's code integrate with the rest of your Lightcurve Explorer pipeline? Write a brief plan.

# %%
# Integration plan:
# 1. Which existing components will use today's code?
#    Answer: 
# 
# 2. What interface (method signatures) will they need?
#    Answer: 
# 
# 3. What tests should I add to verify integration?
#    Answer: 
# 
# 4. Any potential conflicts or breaking changes?
#    Answer:

# %% [markdown]
# ---
# ## Self-Assessment
#
# Rate your understanding of this week's concepts:

# %%
# Rate 1-5 (1=confused, 5=confident)
understanding = {
    "Main concept": 0,        # Rate yourself
    "Implementation": 0,       # Could you build it from scratch?
    "Testing": 0,              # Can you write good tests?
    "Connection to pipeline": 0, # See how it fits?
}

for topic, rating in understanding.items():
    print(topic + ": " + str(rating) + "/5")

# What would help you improve?
# Answer:

# %% [markdown]
# ---
# ## Completion Checklist
#
# Before submitting, verify:
#
# - [ ] Must-Pass: Class created with __init__ and at least 2 methods
# - [ ] Must-Pass: All tests pass
# - [ ] Standard: Extended with error handling and additional methods
# - [ ] Stretch: Extra features implemented (optional)
# - [ ] Code has docstrings on all classes and methods
# - [ ] No logic copied from core notebook (you adapted it)
# - [ ] Edge case tests written
# - [ ] Design diagram drawn
# - [ ] Self-assessment completed

# %% [markdown]
# ---
# ## Reflection (Required - Complete before submitting)
#
# In the cell below, write 3-5 bullet points:
# 1. **What I learned today:**
# 2. **What was hardest:**
# 3. **What I still don't understand:**
# 4. **What I will review before next week:**
# 5. **If I used AI tools, what for:**

# %%
# YOUR REFLECTION (write as comments or as a multi-line string)
reflection = """
- What I learned:
- What was hardest:
- What I still don't understand:
- What I will review:
- AI tools used (if any):
"""
print(reflection)
