# %% [markdown]
# # OOP Week 1 Homework -- OOP Kickoff: Classes & Objects
#
# **Due:** Before next week's session
# **Estimated time:** 2-3 hours
# **Grading:** Must-pass (exercises 1-5), Standard (6-8), Stretch (9-12)
#
# ---
#
# ## Instructions
#
# 1. Complete exercises **in order** -- they build on each other
# 2. **Run each cell** and verify it works before moving on
# 3. **Write comments** explaining your thinking
# 4. **Test** your code (at minimum: does it run without errors?)
# 5. Submit this notebook with all cells executed

# %% [markdown]
# ---
# ## Exercise 1 [Must-Pass]: Create a Dog class
#
# Create a `Dog` class with attributes `name`, `breed`, and `age`. Add a method `bark()` that prints a message.

# %%
# YOUR CODE HERE

class Dog:
    pass

# %% [markdown]
# ---
# ## Exercise 2 [Must-Pass]: Add methods to Dog
#
# Add `birthday()` (increments age) and `describe()` (prints all info).

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 3 [Must-Pass]: Create a BankAccount class
#
# Attributes: `owner`, `balance` (default 0). Methods: `deposit(amount)`, `withdraw(amount)`, `get_balance()`.
# `withdraw` should print a warning if insufficient funds.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 4 [Must-Pass]: Multiple instances
#
# Create 3 Dog objects and 2 BankAccount objects. Verify they have independent state.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 5 [Must-Pass]: Add __str__ to both classes
#
# Add `__str__` methods that return readable strings. Example: `Dog(Rex, Labrador, 5 years)`

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 6 [Standard]: Procedural vs OOP comparison
#
# Write a procedural version of BankAccount using functions and dicts. Then compare: which is easier to use? Write your answer as a comment.

# %%
# Procedural version

# YOUR CODE HERE

# Comparison (write as comments):
#

# %% [markdown]
# ---
# ## Exercise 7 [Standard]: Counter class
#
# Create a `Counter` class with `increment()`, `decrement()`, `reset()`, and `value` attribute. Add a `history` list that records every change.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 8 [Standard]: Student class with grades
#
# Create a `Student` class that stores a name and list of grades. Methods: `add_grade(grade)`, `average()`, `highest()`, `lowest()`, `is_passing()` (average >= 60).

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 9 [Stretch]: Inventory Item
#
# Create an `InventoryItem` class with `name`, `quantity`, `price`. Methods: `restock(amount)`, `sell(amount)` (with stock check), `total_value()`. Add `__str__`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 10 [Stretch]: Design before code
#
# BEFORE writing any code, draw an ASCII class diagram for a `Library` system with `Book` and `Member` classes. Include attributes and methods. Then implement it.

# %%
# ASCII diagram (in comments):
# +--------+
# | Book   |
# +--------+
# | ...    |
# +--------+

# Implementation:

# %% [markdown]
# ---
# ## Exercise 11 [Stretch]: Error handling
#
# Add error handling to your BankAccount: raise `ValueError` if deposit/withdraw amount is negative. Write tests that verify the errors are raised.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 12 [Stretch]: Reflection: Procedural vs OOP
#
# Write a 5-sentence paragraph (as a string) explaining when you would choose OOP over procedural programming and vice versa. Give a concrete example of each.

# %%
reflection = """
# YOUR REFLECTION HERE
"""
print(reflection)

# %% [markdown]
# ---
# ## Submission Checklist
#
# - [ ] Exercises 1-5 complete and running (Must-Pass)
# - [ ] Exercises 6-8 complete (Standard)
# - [ ] Exercises 9-12 attempted (Stretch)
# - [ ] All cells executed (no errors)
# - [ ] Comments explain your thinking
