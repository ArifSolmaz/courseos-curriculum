# %% [markdown]
# # CP1 Week 11 Studio — Lightcurve Explorer
# **Track:** Space/Astro
# **Task:** Add robust error handling to clean_data() — skip and count bad rows
# **Deliverable:** clean_data() reports skipped counts

# %%
# === SETUP (run this first) ===
# If running in Google Colab, uncomment and run the lines below:
# !git clone https://github.com/YOUR-ORG/YOUR-REPO.git
# %cd YOUR-REPO

import sys, os
# Add src to path so we can import project modules
if os.path.exists('src'):
    sys.path.insert(0, 'src')
elif os.path.exists('../src'):
    sys.path.insert(0, '../src')
elif os.path.exists('../../src'):
    sys.path.insert(0, '../../src')

print("Setup complete! Ready to work.")

# %% [markdown]
# ---
# ## Your Track Data
#
# **Lightcurve Explorer** works with star brightness (flux) measurements over time.
#
# Here's your sample data:

# %%
# Sample data for Space/Astro track
sample_data = [{"time": 0.0, "flux": 1.000, "sector": "A"},
 {"time": 0.1, "flux": 0.998, "sector": "A"},
 {"time": 0.2, "flux": 0.700, "sector": "A"},
 {"time": 0.3, "flux": 0.985, "sector": "A"},
 {"time": 0.4, "flux": -0.1, "sector": "B"},
 {"time": 0.5, "flux": 1.010, "sector": "B"}]

print(f"Loaded {len(sample_data)} rows")
for row in sample_data:
    print(f"  {row}")

# %% [markdown]
# ---
# ## Must-Pass Core
#
# You MUST complete this before moving on.

# %%
# Must-pass: Run pipeline end-to-end for Lightcurve Explorer
config = {
    "project_name": "lightcurve_explorer",
    "track": "space",
    "version": "v1",
    "value_column": "flux",
    "threshold": 0.9,
}

# TODO: Implement or import your pipeline functions
# data = load_data(config)
# cleaned = clean_data(data, config)
# results = analyze(cleaned, config)
# figures = plot(cleaned, results, config)
# exported = export_results(cleaned, results, figures, config)

print("TODO: Uncomment and implement the pipeline steps above")
print("Must-pass core: check your implementation!")

# %% [markdown]
# ---
# ## Standard Target
#
# If you finished the must-pass core, continue here:

# %%
# Standard target for Week 11
# Add robust error handling to clean_data() — skip and count bad rows

# TODO: Extend your implementation to handle:
# 1. Multiple data formats
# 2. Better error messages
# 3. More detailed output

print("Work on the standard target now...")

# %% [markdown]
# ---
# ## Stretch (Optional)
#
# For fast students who finished the standard target:

# %%
# Stretch goal for Week 11
# Add one extra feature that makes your Lightcurve Explorer better.
# Ideas:
# - Extra validation rule
# - Additional metric or classification
# - Better formatting or reporting

print("Stretch goal: add your improvement here")

# %% [markdown]
# ---
# ## Take-Home Tasks
#
# 1. Make sure your must-pass core works completely
# 2. If you didn't finish the standard target, complete it at home
# 3. Review the core notebook concepts from Week 11
# 4. Push your code to GitHub

# %% [markdown]
# ---
# ## Reflection (Required - Complete before submitting)
#
# In the cell below, write 3-5 bullet points:
# 1. **What I learned today:**
# 2. **What was hardest:**
# 3. **What I still don't understand:**
# 4. **What I will review before next week:**
# 5. **If I used AI tools, what for:**

# %%
# YOUR REFLECTION (write as comments or as a multi-line string)
reflection = """
- What I learned:
- What was hardest:
- What I still don't understand:
- What I will review:
- AI tools used (if any):
"""
print(reflection)
