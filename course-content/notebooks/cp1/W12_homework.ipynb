# %% [markdown]
# # CP1 Week 12 Homework -- File I/O: Reading & Writing
#
# **Due:** Before next week's session
# **Estimated time:** 2-4 hours
#
# ## Instructions
#
# - **Review (R1-R4):** Check your understanding. All required.
# - **Practice (P1-P5):** Apply concepts to problems. All required.
# - **Challenge (C1-C3):** Stretch exercises. Optional but recommended.
# - **Mini-Project (M1):** Build something complete. Optional but highly recommended.
#
# Difficulty: Easy / Medium / Hard / Challenge is marked for each exercise.

# %% [markdown]
# ---
# ## Review Exercises (Easy)
#
# These check that you understood the core concepts:

# %%
# R1: What was the main concept in Week 12?
# Answer:

# %%
# R2: How does this week's concept connect to your pipeline?
# Answer:

# %%
# R3: Write one example demonstrating this week's key concept.

# %%
# R4: What was the hardest part of Week 12? Why?
# Answer:

# %% [markdown]
# ---
# ## Practice Exercises (Medium)
#
# Apply the concepts to solve problems:

# %%
# P1: Apply this week's concept to a simple example.

# %%
# P2: Modify the core notebook example for a different dataset.

# %%
# P3: Write a function that demonstrates this week's concept.

# %%
# P4: Test your function with 3+ inputs including edge cases.

# %%
# P5: Integrate this week's concept into your pipeline.

# %% [markdown]
# ---
# ## Challenge Exercises (Hard -- Optional but Recommended)

# %%
# C1: Extend this week's concept with extra features.

# %%
# C2: Research a related Python feature and demonstrate it.

# %%
# C3: Combine this week's concept with a previous week's concept.

# %% [markdown]
# ---
# ## Mini-Project (Challenge -- Optional but Highly Recommended)

# %%
# MINI-PROJECT: Build a standalone tool using Week 12 concepts.
# Requirements:
# - Uses 3+ concepts from this week
# - Works with sample data
# - Handles 2+ edge cases
# - Clear formatted output

# %% [markdown]
# ---
# ## Self-Check
#
# Before submitting, verify:

# %%
checklist = [
    "All Review exercises (R1-R4) answered",
    "All Practice exercises (P1-P5) completed",
    "Code runs without errors",
    "Output is clear and formatted",
    "Edge cases considered",
]

print("=== Homework 12 Self-Check ===")
for item in checklist:
    print(f"  [ ] {item}")
print()
print("Mark each [x] when done!")
