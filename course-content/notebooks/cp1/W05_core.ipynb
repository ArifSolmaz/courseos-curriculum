# %% [markdown]
# # CP1 Week 5 — Loops: Scanning Data
#
# ## Learning Objectives
# - Use `for` loops to iterate over lists and ranges
# - Use `while` loops for condition-based repetition
# - Accumulate values: sum, count, min, max, mean
# - Compute summary statistics on data

# %%
# === SETUP (run this first) ===
# If running in Google Colab, uncomment and run the lines below:
# !git clone https://github.com/YOUR-ORG/YOUR-REPO.git
# %cd YOUR-REPO

import sys, os
# Add src to path so we can import project modules
if os.path.exists('src'):
    sys.path.insert(0, 'src')
elif os.path.exists('../src'):
    sys.path.insert(0, '../src')
elif os.path.exists('../../src'):
    sys.path.insert(0, '../../src')

print("Setup complete! Ready to work.")

# %% [markdown]
# ---
# ## Part 1: The for Loop
#
# A `for` loop repeats code for each item in a sequence:

# %%
# Loop over a list
readings = [25.0, 22.5, 28.1, 21.3, 26.7]

for value in readings:
    print(f"Reading: {value}")

# %%
# Loop with range()
for i in range(5):        # 0, 1, 2, 3, 4
    print(f"Step {i}")

print()
for i in range(2, 8):     # 2, 3, 4, 5, 6, 7
    print(f"Step {i}")

print()
for i in range(0, 20, 5): # 0, 5, 10, 15 (step by 5)
    print(f"Step {i}")

# %% [markdown]
# ---
# ## Part 2: Accumulation Patterns
#
# The most important loop patterns for data analysis:

# %%
data = [10, 25, 30, 15, 20, 35, 5, 40]

# Pattern 1: SUM
total = 0
for value in data:
    total = total + value
print(f"Sum: {total}")

# Pattern 2: COUNT
count = 0
for value in data:
    count = count + 1
print(f"Count: {count}")

# Pattern 3: MEAN (average)
mean = total / count
print(f"Mean: {mean}")

# Pattern 4: MIN
smallest = data[0]  # start with first value
for value in data:
    if value < smallest:
        smallest = value
print(f"Min: {smallest}")

# Pattern 5: MAX
largest = data[0]
for value in data:
    if value > largest:
        largest = value
print(f"Max: {largest}")

# %% [markdown]
# **Expected Output:**
# ```
# Sum: 180
# Count: 8
# Mean: 22.5
# Min: 5
# Max: 40
# ```

# %% [markdown]
# ### Try It

# %%
# TODO: Compute sum, count, mean, min, max for this data
# Do NOT use built-in sum(), min(), max() — use loops!

temps = [22.1, 19.8, 25.3, 18.6, 23.4, 27.0, 20.5]

# Your code here

# %% [markdown]
# ---
# ## Part 3: Counting with Conditions

# %%
data = [10, 25, 30, 15, 20, 35, 5, 40, 22, 28]
threshold = 25

# Count values above threshold
above = 0
below = 0
for value in data:
    if value > threshold:
        above += 1
    else:
        below += 1

print(f"Above {threshold}: {above}")
print(f"At or below {threshold}: {below}")

# %% [markdown]
# ---
# ## Part 4: The while Loop

# %%
# while loop: repeats as long as condition is True
count = 0
while count < 5:
    print(f"Count is {count}")
    count += 1  # IMPORTANT: must update the variable!
print("Done!")

# Danger: if you forget count += 1, the loop runs FOREVER!
# (If that happens, click the stop button in Colab)

# %% [markdown]
# ---
# ## Part 5: Computing Stats for Your Pipeline

# %%
def compute_stats(values):
    """Compute basic statistics using only loops.
    
    Returns dict with: count, sum, mean, min, max, std
    """
    if not values:
        return {"count": 0, "sum": 0, "mean": 0, "min": 0, "max": 0, "std": 0}
    
    n = 0
    total = 0
    smallest = values[0]
    largest = values[0]
    
    for v in values:
        n += 1
        total += v
        if v < smallest:
            smallest = v
        if v > largest:
            largest = v
    
    mean = total / n
    
    # Standard deviation
    sum_sq_diff = 0
    for v in values:
        sum_sq_diff += (v - mean) ** 2
    std = (sum_sq_diff / n) ** 0.5
    
    return {
        "count": n,
        "sum": round(total, 4),
        "mean": round(mean, 4),
        "min": round(smallest, 4),
        "max": round(largest, 4),
        "std": round(std, 4),
    }

# Test
test_data = [10, 20, 30, 40, 50]
stats = compute_stats(test_data)
for key, val in stats.items():
    print(f"  {key}: {val}")

# %% [markdown]
# ---
# ## Mini-Quiz

# %%
# Q1: How many times does this loop run?
for i in range(3, 10, 2):
    pass
# Answer: ___

# Q2: What is the accumulator pattern?
# Answer: ___

# Q3: When should you use while instead of for?
# Answer: ___

# %% [markdown]
# ---
# ## Homework
#
# ### Easy

# %%
# HW1: Use a for loop to print the first 20 multiples of 7

# %%
# HW2: Compute the sum and mean of: [3.5, 7.2, 1.8, 9.4, 5.1]
# using loops (not built-in functions)

# %%
# HW3: Count how many values in this list are between 20 and 30 (inclusive)
data = [15, 22, 31, 25, 18, 28, 33, 20, 27, 30]

# %% [markdown]
# ### Medium

# %%
# HW4: Write compute_stats() and test on 3 different datasets
# Print a formatted table of results

# %%
# HW5: Find the second-largest value in a list using a loop
# (don't sort — use two tracking variables)
data = [45, 12, 67, 23, 89, 34, 56]

# %%
# HW6: Compute a "running sum" — a new list where each element
# is the sum of all previous elements
# [1, 2, 3, 4] → [1, 3, 6, 10]

# %% [markdown]
# ### Challenge

# %%
# HW7: Write a function that computes the median WITHOUT using sort()
# Hint: find the middle value by counting how many values are smaller

# %%
# HW8: Write a standard_deviation() function from scratch
# and verify it gives the same result as compute_stats()

# %% [markdown]
# ---
# ## Reflection (Required - Complete before submitting)
#
# In the cell below, write 3-5 bullet points:
# 1. **What I learned today:**
# 2. **What was hardest:**
# 3. **What I still don't understand:**
# 4. **What I will review before next week:**
# 5. **If I used AI tools, what for:**

# %%
# YOUR REFLECTION (write as comments or as a multi-line string)
reflection = """
- What I learned:
- What was hardest:
- What I still don't understand:
- What I will review:
- AI tools used (if any):
"""
print(reflection)
